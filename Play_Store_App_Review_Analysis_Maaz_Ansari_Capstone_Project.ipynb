# %% [markdown]
# <a href="https://colab.research.google.com/github/MaazAnsari-OO7/Play-Store-App-Review-Analysis/blob/main/Play_Store_App_Review_Analysis_Maaz_Ansari_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> The Play Store apps data has enormous potential to drive app-making businesses to success. Actionable insights can be drawn for developers to work on and capture the Android market. </b>
#
# ## <b> Each app (row) has values for catergory, rating, size, and more. Another dataset contains customer reviews of the android apps.</b>
#
# ## <b> Explore and analyze the data to discover key factors responsible for app engagement and success. </b>

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
playstore_data_path = '/content/drive/MyDrive/Capstone Files/EDA/Play Store Data.csv'
user_review_data_path = '/content/drive/MyDrive/Capstone Files/EDA/User Reviews.csv'

# %%
playstore_df = pd.read_csv(playstore_data_path)
review_df = pd.read_csv(user_review_data_path)

# %% [markdown]
# # Exploring Playstore and User Review Dataframe.

# %%
playstore_df.shape

# %%
playstore_df.head()

# %%
playstore_df.tail()

# %%
playstore_df.info()

# %%
review_df.shape

# %%
review_df.info()

# %%
review_df.head()

# %%
review_df.tail()

# %% [markdown]
# # Data Cleaning.

# %%
df = playstore_df.copy()

# %% [markdown]
# # 1- Converting "Review" column type from "object" to "int".

# %%
df['Reviews']=df['Reviews'].apply(lambda x : eval(x))
# Out:
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-14-377d2d6462cf>", line 1, in <module>
#     df['Reviews']=df['Reviews'].apply(lambda x : eval(x))
#
#   File "/usr/local/lib/python3.7/dist-packages/pandas/core/series.py", line 4357, in apply
#     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
#   File "/usr/local/lib/python3.7/dist-packages/pandas/core/apply.py", line 1043, in apply
#     return self.apply_standard()
#
#   File "/usr/local/lib/python3.7/dist-packages/pandas/core/apply.py", line 1101, in apply_standard
#     convert=self.convert_dtype,
#
#   File "pandas/_libs/lib.pyx", line 2859, in pandas._libs.lib.map_infer
#
#   File "<ipython-input-14-377d2d6462cf>", line 1, in <lambda>
#     df['Reviews']=df['Reviews'].apply(lambda x : eval(x))
#
#   File "<string>", line 1
#     3.0M
#        ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# ## While converting Reviews into "int" type we found some Error.
# ## Which show that one of the value in review column is 3.0M.
# ## So we have to remove that row from the data set.

# %%
# Finding the row index of that value.
df[df['Reviews']=='3.0M']
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %% [markdown]
# ## We have found that index no 10472 contain the value 3.0M.

# %%
# Dropping that index value using drop method and reseting index again.
df = df.drop(10472).reset_index(drop=True)

# %%
# Evaluating the values.
df['Reviews']=df['Reviews'].apply(lambda x : eval(x))

# %% [markdown]
# # 2- Converting "Size" type from "object" to "float".

# %%
df.tail()
# Out:
#                                                  App             Category  \
# 10835                               Sya9a Maroc - FR               FAMILY
# 10836               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                         Parkinson Exercices FR              MEDICAL
# 10838                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews                Size     Installs  Type Price  \
# 10835     4.5       38                 53M       5,000+  Free     0
# 10836     5.0        4                3.6M         100+  Free     0
# 10837     NaN        3                9.5M       1,000+  Free     0
# 10838     4.5      114  Varies with device       1,000+  Free     0
# 10839     4.5   398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# 10835       Everyone          Education     July 25, 2017                1.48
# 10836       Everyone          Education      July 6, 2018                 1.0
# 10837       Everyone            Medical  January 20, 2017                 1.0
# 10838     Mature 17+  Books & Reference  January 19, 2015  Varies with device
# 10839       Everyone          Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 10835          4.1 and up
# 10836          4.1 and up
# 10837          2.2 and up
# 10838  Varies with device
# 10839  Varies with device

# %% [markdown]
# ### It is observed that "Size column contain values in MB (M), kb(k) and "Varies with device".

# %%
df[df['Size']=='Varies with device'].shape
# Out:
# (1695, 13)

# %% [markdown]
# ## As we can see there are **1695** rows that has **"Varies with device"** value in **"Size"** column. Replacing this value with mean value will affect the visualization. Replacing **Varies with device** value with np.NaN which is of float type.

# %%
def converting_size_into_float(string):
  '''
  This function helps in removing 'M'(MB) and 'k'(kb) which are present at the end of the string and replace 'Varies with device' with np.NaN. This function also evaluate the values present. 
  '''
  
  if string[-1] == 'M':
    return eval(string.strip('M'))

  elif string[-1] == 'k':
    a =string.strip('k')
    b = str(round(eval(a)/1024,1))
    return eval(b)

  elif string == 'Varies with device':
    string = np.NaN  
    return string
  else:
    return eval(string)

# %%
# Applying defined function.
df['Size']= df['Size'].apply(lambda x : converting_size_into_float(x))

# %% [markdown]
# # 3- Converting "Install" type from "object to "int".

# %% [markdown]
# ## In **Install** column values are of **object** type and contain '+' and ',' in them. So we are going remove '+' and ',' from the values and then convert them into **int** type using **eval** method.

# %%
# Creating function to remove + and ,.
def remove_plus_and_comma(string):
  '''
  This function removes '+' and ',' from the string.
  '''
  string = string.replace(',','')
  string = string.strip('+')
  return string

# %%
# Applying defined function on the column and evaluating those values.
df['Installs'] = df['Installs'].apply(lambda x: eval(remove_plus_and_comma(x)))

# %% [markdown]
# # 4- Converting "Price" type from "object" to "float".

# %% [markdown]
# ## **Price** column value has $ symbol in them and they are of object type. we'll remove the symbol and change the type.

# %%
# Creating function to remove $ symbol.
def remove_sign(string):
  '''
  This function removes $ symbol from the string and convert given string data type from 'str' to 'float'.
  '''
  return round(float(string.strip('$')),2)

# %%
# Applying the function.
df['price_in_dollar'] = df['Price'].apply(lambda x : remove_sign(x))

# %% [markdown]
# # 5- Converting **Last Update** type from "object" to "datetime".

# %%
# Converting str into datetime formate using 'to_datetime' function.
df['Last Updated'] = pd.to_datetime(df['Last Updated'])

# %% [markdown]
# # 6- Handling Rating column

# %%
len(df[df['Rating'].isnull()]['Rating'])
# Out:
# 1474

# %% [markdown]
# ## Rating column contain 1474 NaN values. We cannot drop this much amount of row from dataset.
# ## We gonna replace all the NaN values with the average of non-null values.

# %%
# Finding average of non-null values from Rating column.
non_null_mean= round(df[~df['Rating'].isnull()]['Rating'].mean(),1)

# %%
# Replacing null values with average rating.
df['Rating'].fillna(value= non_null_mean, inplace=True)

# %% [markdown]
# # 7- Removing Null value from "Type" column.

# %% [markdown]
# ## **Type** column contain only one NaN value.

# %%
df[df['Type'].isnull()]['Type']
# Out:
# 9148    NaN
# Name: Type, dtype: object

# %% [markdown]
# ## It is observed that Type column contain Null value at index 9148.

# %%
# Removing row having index 9148 and reseting the index.
df = df.drop(9148).reset_index(drop=True)

# %% [markdown]
# # 8- Removing Null values from "Current Ver".

# %%
df[df['Current Ver'].isnull()]['Current Ver'].shape
# Out:
# (8,)

# %% [markdown]
# ## Number of Null value present in the 'Current Ver' column is 8.

# %%
# Removing the rows containing Null values from Dataframe.
df = df[~df['Current Ver'].isnull()]

# %% [markdown]
# # 9- Removing Null values from "Android Ver" column.

# %%
len(df[df['Android Ver'].isnull()]['Android Ver'])
# Out:
# 2

# %% [markdown]
# ## Number of Null values present in the "Android Ver" column is 2.

# %%
# Removing Rows containing Null value from dataframe.
df= df[~df['Android Ver'].isnull()]

# %% [markdown]
# ## Android Ver type is of object and there are different values. we'll get the create another column in the Dataframe which will store the minimum android version for the App.

# %%
# creating a function to obtain minimum version for the App.
def get_ver(string):
  '''
  This function is used to obtain minimum android version required.
  '''

  if string =='Varies with device':
    return eval('1.0')
  else:
    string = string[0:3]
    return eval(string)

# %%
# Applying the function.
df['min_ver']=df['Android Ver'].apply(lambda x : get_ver(x))

# %% [markdown]
# # Checking and Removing Duplicate values from the data set.

# %% [markdown]
# ## As we can see in the Dataframe only one column that contain **UNIQUE** value which cannot be repeate and that column is **App** column.

# %%
# Creating temperory dataframe to find the number of duplicate apps.
a = df['App'].value_counts().reset_index()

# %%
# Finding the number of duplicate rows.
len(a[a['App']>=2])
# Out:
# 798

# %% [markdown]
# ### As we can see above Dataframe contains 798 duplicate rows.

# %%
# Removing DUPLICATES from the Dataframe.
df=df.drop_duplicates(subset = 'App')

# %% [markdown]
# Reseting index

# %%
df=df.reset_index()

# %%
df.drop(['index'],axis = 1,inplace=True)

# %%
df.shape
# Out:
# (9648, 15)

# %% [markdown]
# ### - After removing "Duplicates" and "NaN values" from the Dataframe we now have a modified Dataframe with 9648 rows and 15 columns.

# %% [markdown]
# ## Cleaning User Review data

# %%
r_df = review_df.copy()

# %%
r_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %%
r_df.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %% [markdown]
# # Handling Null values in User data review Dataframe.

# %%
r_df[r_df['Translated_Review'].isnull()].shape
# Out:
# (26868, 5)

# %% [markdown]
# ## There are 26868 Null Values in T**ranslated Review** column.

# %% [markdown]
# ## Removing NaN values from **Translated_Review** column, cause the rows containing NaN values are of no use and we cannot impute null values for these column.
# ## If there is no review then there will be no sentiment.
# ## Therefore, We will remove all the rows that contains NaN values in Translated_Review columm.

# %%
r_df= r_df[~r_df['Translated_Review'].isnull()]

# %% [markdown]
# Reseting index

# %%
r_df= r_df.reset_index()

# %%
r_df.drop(['index'],axis=1,inplace=True)

# %%
r_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37427 entries, 0 to 37426
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     37427 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37427 non-null  object
#  3   Sentiment_Polarity      37427 non-null  float64
#  4   Sentiment_Subjectivity  37427 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 1.4+ MB

# %% [markdown]
# # **Data Visualization**

# %% [markdown]
# # Q- Total number of app in each category.

# %%
# Creating temperory dataset which contain unique categories and no of apps in that category.
cat_df = df.groupby('Category')['App'].count().sort_values(ascending = False).reset_index()

# %%
# Plotting Bar graph.
fig =px.bar(cat_df,x= 'Category',y= 'App',labels={'App':'Number of Apps'},text_auto=True)
fig.update_layout(title_text='Number of Apps in each Category', title_x=0.5,titlefont=dict(size =22, color='black', family='Arial, sans-serif'))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="368f8cc8-cbef-482b-a4f4-423d01bc7c8c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("368f8cc8-cbef-482b-a4f4-423d01bc7c8c")) {                    Plotly.newPlot(                        "368f8cc8-cbef-482b-a4f4-423d01bc7c8c",                        [{"alignmentgroup":"True","hovertemplate":"Category=%{x}<br>Number of Apps=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":["FAMILY","GAME","TOOLS","BUSINESS","MEDICAL","PERSONALIZATION","PRODUCTIVITY","LIFESTYLE","FINANCE","SPORTS","COMMUNICATION","HEALTH_AND_FITNESS","PHOTOGRAPHY","NEWS_AND_MAGAZINES","SOCIAL","BOOKS_AND_REFERENCE","TRAVEL_AND_LOCAL","SHOPPING","DATING","VIDEO_PLAYERS","MAPS_AND_NAVIGATION","EDUCATION","FOOD_AND_DRINK","ENTERTAINMENT","AUTO_AND_VEHICLES","LIBRARIES_AND_DEMO","WEATHER","HOUSE_AND_HOME","EVENTS","ART_AND_DESIGN","PARENTING","COMICS","BEAUTY"],"xaxis":"x","y":[1828,959,825,420,395,374,374,369,345,325,315,288,281,254,239,221,219,202,171,163,131,119,112,102,85,83,79,74,64,63,60,56,53],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.22222222222222 ...

# %% [markdown]
# ## **Observation:**
# ### As we can see most number of apps in the Playstore are of **Family** category followed by **Game** and **Tools** category.
# ### **Beauty** and **Comics** category has least number of apps.

# %% [markdown]
# # Q-Top 10 apps of Free Type.

# %%
# Dataframe of free type apps.
free_df=df[df['Type']=='Free']

# %%
# Top 10 free app by installs.
free_df[['App','Installs']].sort_values(by='Installs',ascending=False).head(10)
# Out:
#                                            App    Installs
# 2928                   Google Play Movies & TV  1000000000
# 1354                            Subway Surfers  1000000000
# 303                                      Gmail  1000000000
# 301               Google Chrome: Fast & Secure  1000000000
# 299                         WhatsApp Messenger  1000000000
# 298   Messenger – Text and Video Chat for Free  1000000000
# 2189                             Google Photos  1000000000
# 2906                                   YouTube  1000000000
# 700                          Google Play Games  1000000000
# 2418                 Maps - Navigate & Explore  1000000000

# %% [markdown]
# # Q- Top 10 apps of Paid type.

# %% [markdown]
# Paid apps can be classified on the basis of **revenue** they generated and not by number of installs.

# %%
# Creating Revenue column.
df['Revenue']= df['Installs']*df['price_in_dollar']

# %%
# Top apps of Paid type.
top_paid_df= df[df['Type']=='Paid'].sort_values(by='Revenue',ascending=False)

# %%
 # Top 10 Paid apps.
top_paid_df[['App','Revenue']].head(10)
# Out:
#                                 App     Revenue
# 1741                      Minecraft  69900000.0
# 4392                      I am rich  39999000.0
# 4396              I Am Rich Premium  19999500.0
# 3206                  Hitman Sniper   9900000.0
# 6362  Grand Theft Auto: San Andreas   6990000.0
# 2258            Facetune - For Free   5990000.0
# 4603        Sleep as Android Unlock   5990000.0
# 7678            DraStic DS Emulator   4990000.0
# 3467       I'm Rich - Trump Edition   4000000.0
# 3463                     💎 I'm rich   3999900.0

# %%
# PLotting Bar graph for top 10 paid apps.
fig = px.bar(top_10_paid_apps,x='App',y='Revenue',color= 'App',text_auto=True)
fig.update_layout(title_text='Top 10 apps in Paid Type by Revenue', title_x=0.5,titlefont=dict(size =22, color='black', family='Arial, sans-serif'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="7e82bcb4-3238-494e-bfa9-e4daf5f05986" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7e82bcb4-3238-494e-bfa9-e4daf5f05986")) {                    Plotly.newPlot(                        "7e82bcb4-3238-494e-bfa9-e4daf5f05986",                        [{"alignmentgroup":"True","hovertemplate":"App=%{x}<br>Revenue=%{y}<extra></extra>","legendgroup":"Minecraft","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Minecraft","offsetgroup":"Minecraft","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Minecraft"],"xaxis":"x","y":[69900000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"App=%{x}<br>Revenue=%{y}<extra></extra>","legendgroup":"I am rich","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"I am rich","offsetgroup":"I am rich","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["I am rich"],"xaxis":"x","y":[39999000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"App=%{x}<br>Revenue=%{y}<extra></extra>","legendgroup":"I Am Rich Premium","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"I Am Rich Premium","offsetgroup":"I Am Rich Premium","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["I Am Rich Premium"],"xaxis":"x","y":[19999500.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"App=%{x}<br>Revenue=%{y}<extra></extra>","legendgroup":"Hitman Sniper","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Hitman Sniper","offsetgroup":"Hitman Sniper","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Hitman Sniper"],"xaxis":"x","y":[9900000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"App=%{x}<br>Revenue=%{y}<extra></extra>","legendgroup":"Grand Theft Auto: San Andreas","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Grand Theft Auto: San Andreas","offsetgroup":"Grand Theft Auto: San Andreas","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Grand Theft Auto: San Andreas"],"xaxis":"x","y":[6990000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"App=%{x}<br>Revenue=%{y}<extra></extra>","legendgroup":"Facetune - For Free","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Facetune - For Free","offsetgroup":"Facetune - For Free","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Facetune - For Free"],"xaxis":"x","y":[5990000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"App=%{x}<br>Revenue=%{y}<extra></extra>","legendgroup":"Sleep as Android Unlock","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Sleep as Android Unlock","offsetgroup":"Sleep as Android Unlock","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Sleep as Android Unlock"],"xaxis":"x","y":[5990000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"App=%{x}<br>Revenue=%{y}<extra></extra>","legendgroup":"DraStic DS Emulator","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"DraStic DS Emulator","offsetgroup":"DraStic DS Emulator","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["DraStic DS Emulator"],"xaxis":"x","y":[4990000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"App=%{x}<br>Revenue=%{y}<extra></extra>","legendgroup":"I'm Rich - Trump Edition","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"I'm Rich - Trump Edition","offsetgroup":"I'm Rich - Trump Edition","orientation":"v","showlegend":true,"textposition":"auto","texttemplate ...

# %% [markdown]
# ## **Observation:**
# ### App which has generated most revenue through download is **Minecraft** making **$69.9Millions**.

# %% [markdown]
# # Q-Number of apps in each category type wise(Free & Paid).

# %%
type_df = df.groupby(['Category','Type'])['App'].count().reset_index()

# %%
# Top Category of Free type.
type_df[type_df['Type']=='Free'].sort_values(by='App',ascending=False).head(2)
# Out:
#    Category  Type   App
# 20   FAMILY  Free  1646
# 26     GAME  Free   877

# %%
# Top Category of Paid type.
type_df[type_df['Type']=='Paid'].sort_values(by='App',ascending=False).head(2)
# Out:
#    Category  Type  App
# 21   FAMILY  Paid  182
# 38  MEDICAL  Paid   83

# %%
# Category with least number of apps in Free type.
type_df[type_df['Type']=='Free'].sort_values(by='App',ascending=False).tail(2)
# Out:
#   Category  Type  App
# 9   COMICS  Free   56
# 4   BEAUTY  Free   53

# %%
# Category with least number of apps in Paid type.
type_df[type_df['Type']=='Paid'].sort_values(by='App',ascending=False).tail(2)
# Out:
#               Category  Type  App
# 32  LIBRARIES_AND_DEMO  Paid    1
# 19              EVENTS  Paid    1

# %%
fig = px.bar(type_df, x='App', y='Category', color='Type',text_auto=True,height=800,labels={'App':'Number of Apps'})
fig.update_layout(title_text='Number of Apps in Each Category type wise', title_x=0.5,titlefont=dict(size =22, color='black', family='Arial, sans-serif'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="1c6eac27-7f96-42fe-8963-d87f294a3b5e" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1c6eac27-7f96-42fe-8963-d87f294a3b5e")) {                    Plotly.newPlot(                        "1c6eac27-7f96-42fe-8963-d87f294a3b5e",                        [{"alignmentgroup":"True","hovertemplate":"Type=Free<br>Number of Apps=%{x}<br>Category=%{y}<extra></extra>","legendgroup":"Free","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Free","offsetgroup":"Free","orientation":"h","showlegend":true,"textposition":"auto","texttemplate":"%{x}","x":[60,82,53,193,408,56,288,165,115,100,63,1646,328,110,877,273,74,82,350,126,312,252,58,294,262,346,200,236,301,748,207,159,71],"xaxis":"x","y":["ART_AND_DESIGN","AUTO_AND_VEHICLES","BEAUTY","BOOKS_AND_REFERENCE","BUSINESS","COMICS","COMMUNICATION","DATING","EDUCATION","ENTERTAINMENT","EVENTS","FAMILY","FINANCE","FOOD_AND_DRINK","GAME","HEALTH_AND_FITNESS","HOUSE_AND_HOME","LIBRARIES_AND_DEMO","LIFESTYLE","MAPS_AND_NAVIGATION","MEDICAL","NEWS_AND_MAGAZINES","PARENTING","PERSONALIZATION","PHOTOGRAPHY","PRODUCTIVITY","SHOPPING","SOCIAL","SPORTS","TOOLS","TRAVEL_AND_LOCAL","VIDEO_PLAYERS","WEATHER"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Type=Paid<br>Number of Apps=%{x}<br>Category=%{y}<extra></extra>","legendgroup":"Paid","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Paid","offsetgroup":"Paid","orientation":"h","showlegend":true,"textposition":"auto","texttemplate":"%{x}","x":[3,3,28,12,27,6,4,2,1,182,17,2,82,15,1,19,5,83,2,2,80,19,28,2,3,24,77,12,4,8],"xaxis":"x","y":["ART_AND_DESIGN","AUTO_AND_VEHICLES","BOOKS_AND_REFERENCE","BUSINESS","COMMUNICATION","DATING","EDUCATION","ENTERTAINMENT","EVENTS","FAMILY","FINANCE","FOOD_AND_DRINK","GAME","HEALTH_AND_FITNESS","LIBRARIES_AND_DEMO","LIFESTYLE","MAPS_AND_NAVIGATION","MEDICAL","NEWS_AND_MAGAZINES","PARENTING","PERSONALIZATION","PHOTOGRAPHY","PRODUCTIVITY","SHOPPING","SOCIAL","SPORTS","TOOLS","TRAVEL_AND_LOCAL","VIDEO_PLAYERS","WEATHER"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222 ...

# %% [markdown]
# ## **Observation:**
# ### In playstore **Family** category has most number of apps in both Free and Paid types.1646 in Free type and 182 in Paid type.
# ### **Comics** and **Beauty** have least number of apps in Free type which is 56 and 53.
# ### In paid type **Libraries And Demo** and **Event** contains only 1 app.

# %% [markdown]
# # Q-Percentage of Review Sentiments.

# %%
# Plotting user sentiments using pie chart.
fig=px.pie(r_df['Sentiment'],names='Sentiment',color='Sentiment')
fig.update_layout(title_text='Sentiments percentage wise', title_x=0.5,titlefont=dict(size =22, color='black', family='Arial, sans-serif'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c0e104ce-4521-4e58-8c32-eacfa736af35" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c0e104ce-4521-4e58-8c32-eacfa736af35")) {                    Plotly.newPlot(                        "c0e104ce-4521-4e58-8c32-eacfa736af35",                        [{"customdata":[["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Neutral"],["Neutral"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Neutral"],["Positive"],["Positive"],["Neutral"],["Positive"],["Positive"],["Positive"],["Neutral"],["Positive"],["Positive"],["Negative"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Negative"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Neutral"],["Positive"],["Positive"],["Positive"],["Positive"],["Neutral"],["Positive"],["Positive"],["Positive"],["Positive"],["Neutral"],["Positive"],["Positive"],["Neutral"],["Positive"],["Positive"],["Positive"],["Negative"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Negative"],["Neutral"],["Neutral"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Negative"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Neutral"],["Neutral"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Neutral"],["Positive"],["Positive"],["Neutral"],["Positive"],["Positive"],["Positive"],["Neutral"],["Positive"],["Positive"],["Negative"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Negative"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Neutral"],["Positive"],["Positive"],["Positive"],["Positive"],["Neutral"],["Positive"],["Positive"],["Positive"],["Positive"],["Neutral"],["Positive"],["Positive"],["Neutral"],["Positive"],["Positive"],["Positive"],["Negative"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Negative"],["Neutral"],["Neutral"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Negative"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Neutral"],["Positive"],["Positive"],["Positive"],["Negative"],["Positive"],["Neutral"],["Positive"],["Neutral"],["Positive"],["Neutral"],["Positive"],["Neutral"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Neutral"],["Neutral"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Neutral"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Negative"],["Positive"],["Positive"],["Neutral"],["Positive"],["Negative"],["Negative"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Negative"],["Positive"],["Negative"],["Neutral"],["Positive"],["Positive"],["Positive"],["Positive"],["Positive"],["Neutral"],["Neutral"],["Positive"],["Neutral"],["Positive"],["Neutral"],["Positive"],["Positive"],["Positive"],["Neutral"],["Positive"],["Ne ...

# %% [markdown]
# ## **Observation:**
# ### Reviews obtain from customers about playstore apps are **64.1%** are of **Positive** sentiment followed  by **Negative** review which is **22.1%** and **13.8%** reviews are of **Neutral** type.

# %% [markdown]
# # Q- Average rating of free and paid type apps category wise.

# %%
#Creating avg dataframe which store Category,Type and avg. Rating columns. 
avg_df=round(df.groupby(['Category','Type'])['Rating'].mean().reset_index(),1)

# %%
# Top Rated category in Free type.
avg_df[avg_df['Type']=='Free'].sort_values(by='Rating',ascending=False).head()
# Out:
#                Category  Type  Rating
# 0        ART_AND_DESIGN  Free     4.4
# 18               EVENTS  Free     4.4
# 4                BEAUTY  Free     4.3
# 5   BOOKS_AND_REFERENCE  Free     4.3
# 14            EDUCATION  Free     4.3

# %%
# Top Rated category in paid type.
avg_df[avg_df['Type']=='Paid'].sort_values(by='Rating',ascending=False).head()
# Out:
#               Category  Type  Rating
# 40  NEWS_AND_MAGAZINES  Paid     4.8
# 15           EDUCATION  Paid     4.8
# 1       ART_AND_DESIGN  Paid     4.7
# 17       ENTERTAINMENT  Paid     4.6
# 50            SHOPPING  Paid     4.5

# %%
fig= px.bar(avg_df, x="Category", y="Rating",color='Type', barmode='group',height=600,text_auto=True,labels={'Rating':'Average Rating'})
fig.update_layout(title_text='Average rating category wise', title_x=0.5,titlefont=dict(size =22, color='black', family='Arial, sans-serif'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="4cf506e2-ccd8-48d9-aa8f-500764a0661c" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4cf506e2-ccd8-48d9-aa8f-500764a0661c")) {                    Plotly.newPlot(                        "4cf506e2-ccd8-48d9-aa8f-500764a0661c",                        [{"alignmentgroup":"True","hovertemplate":"Type=Free<br>Category=%{x}<br>Average Rating=%{y}<extra></extra>","legendgroup":"Free","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Free","offsetgroup":"Free","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["ART_AND_DESIGN","AUTO_AND_VEHICLES","BEAUTY","BOOKS_AND_REFERENCE","BUSINESS","COMICS","COMMUNICATION","DATING","EDUCATION","ENTERTAINMENT","EVENTS","FAMILY","FINANCE","FOOD_AND_DRINK","GAME","HEALTH_AND_FITNESS","HOUSE_AND_HOME","LIBRARIES_AND_DEMO","LIFESTYLE","MAPS_AND_NAVIGATION","MEDICAL","NEWS_AND_MAGAZINES","PARENTING","PERSONALIZATION","PHOTOGRAPHY","PRODUCTIVITY","SHOPPING","SOCIAL","SPORTS","TOOLS","TRAVEL_AND_LOCAL","VIDEO_PLAYERS","WEATHER"],"xaxis":"x","y":[4.4,4.2,4.3,4.3,4.1,4.2,4.1,4.0,4.3,4.1,4.4,4.2,4.1,4.2,4.2,4.2,4.2,4.2,4.1,4.1,4.2,4.1,4.3,4.3,4.2,4.2,4.2,4.2,4.2,4.0,4.1,4.1,4.2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Type=Paid<br>Category=%{x}<br>Average Rating=%{y}<extra></extra>","legendgroup":"Paid","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Paid","offsetgroup":"Paid","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["ART_AND_DESIGN","AUTO_AND_VEHICLES","BOOKS_AND_REFERENCE","BUSINESS","COMMUNICATION","DATING","EDUCATION","ENTERTAINMENT","EVENTS","FAMILY","FINANCE","FOOD_AND_DRINK","GAME","HEALTH_AND_FITNESS","LIBRARIES_AND_DEMO","LIFESTYLE","MAPS_AND_NAVIGATION","MEDICAL","NEWS_AND_MAGAZINES","PARENTING","PERSONALIZATION","PHOTOGRAPHY","PRODUCTIVITY","SHOPPING","SOCIAL","SPORTS","TOOLS","TRAVEL_AND_LOCAL","VIDEO_PLAYERS","WEATHER"],"xaxis":"x","y":[4.7,4.3,4.2,4.1,4.1,3.8,4.8,4.6,4.2,4.3,3.9,4.4,4.4,4.3,4.2,4.2,3.9,4.2,4.8,3.4,4.4,4.1,4.2,4.5,3.9,4.2,4.2,4.1,4.1,4.4],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0 ...

# %% [markdown]
# ## **Observation:**
# ### It is observed that in **Free** type **ART AND DESIGN** and **EVENTS** are the highest rated category in playstore with a rating of 4.4.
# ### In **Paid** type **NEWS AND MAGAZINES** and **EDUCATION** are the highest rated category in playstore with a rating of 4.8.
